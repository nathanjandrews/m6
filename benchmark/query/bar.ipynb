# %%
import matplotlib.pyplot as plt

# Data
nodes = [10, 20, 30, 40, 50]
procedure_times = [8.0673, 10.6443, 14.2983, 20.5344, 28.2214]

# Calculate average procedure time
# average_procedure_time = [sum(procedure_times[i:i+3]) / 3 for i in range(0, len(procedure_times), 3)]

# Calculate QPS (queries per second)
qps = [1 / t * 1000 for t in procedure_times]

# Create the line chart
plt.figure(figsize=(10, 6))
plt.plot(nodes, procedure_times, marker='o', label='Average Latency (ms)')
# plt.plot(nodes, qps, marker='s', label='Queries per Second (QPS)')
plt.xlabel('Number of Nodes')
# plt.ylabel('Time (ms) / QPS')
plt.ylabel('Time (ms)')
# plt.title('Query Latency and Queries per Second')
plt.title('Query Latency')
plt.grid(True)
plt.legend()
plt.show()
